# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib
import requests
import nltk
import string
import re
# import itable
import operator
import os
from collections import Counter
from nltk.corpus import stopwords
from nltk.stem.porter import *
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
from wordcloud import WordCloud
# from prettytable import PrettyTable
# %matplotlib inline

# %%
ddff2 = pd.read_csv("all_9_vs_all.csv", header = None, names = ["Obs", "Term", "Attr Score"])
ddff2 = ddff2[ddff2.Term != 'Term']
ddff2.head()
#ddff2['Attr Score'] = ddff2['Attr Score'].apply(pd.to_numeric)
ddff2['Attr Score'] = pd.to_numeric(ddff2['Attr Score'])
pd.options.display.float_format = '{:,.0f}'.format
# ddff2 = pd.read_csv("big_clus9.csv", header = None, names = ["Term", "Freq"])
# ddff2.head()

# %%
# Convert into dictionary
#tf_dict = ddff2.set_index('Term').to_dict()
tf_dict = ddff2.set_index('Term')['Attr Score'].to_dict()
#type(tf_dict.values()[0])

#tf_dict.values()[0].pop('tumor')
#tf_dict.values()[0].pop('trauma')
#tf_dict.values()[0].pop('soft_tissue')
#tf_dict.values()[0].pop('bones')
#tf_dict.values()[0].pop('may_be')
#tf_dict.values()[0].pop('coarctation')

# %%
#sorted(tf_dict.values()[0].items(), key = lambda x: x[1], reverse = True)
sorted(tf_dict)
# Out:
# ['123',
#  '50',
#  '99m_mdp',
#  '99m_pertechnetate',
#  '_andrea_watson',
#  '_andrew_poznanski',
#  '_images_1',
#  'a_ring',
#  'abdomen',
#  'abdominal',
#  'abdominal_aorta',
#  'abdominal_cavity',
#  'abdominal_musculature',
#  'abdominal_vasculature',
#  'abdominal_wall',
#  'abdominoplasty',
#  'abducens_nerve',
#  'ablation',
#  'abnormal',
#  'abnormal_accumulation_of_fluid',
#  'abortion',
#  'abscess',
#  'absence',
#  'absence_of_flow',
#  'absent',
#  'ace_inhibitor',
#  'acetabular_fossa',
#  'acetabular_labrum',
#  'acetabulum',
#  'achalasia',
#  'achilles_tendon',
#  'achondroplasia',
#  'acl_tear',
#  'acquired',
#  'acquisition',
#  'acromegaly',
#  'acromioclavicular_joint',
#  'acromion',
#  'acroosteolysis',
#  'acute',
#  'acute_abdomen',
#  'acute_tubular_necrosis',
#  'adamantinoma',
#  'additional_radiology_images_from_dr',
#  'adenitis',
#  'adenocarcinoma',
#  'adenoid',
#  'adenoma',
#  'adenomatous',
#  'adenopathy',
#  'adequate',
#  'adhesion',
#  'adhesive',
#  'adipose_tissue',
#  'adjacent',
#  'adnexa',
#  'adolescent',
#  'adrenal_cortex',
#  'adrenal_cortical_adenoma',
#  'adrenal_gland',
#  'adrenal_medulla',
#  'adrenals',
#  'adult',
#  'advanced',
#  'aerated',
#  'after',
#  'agenesis',
#  'aggressive',
#  'aggressive_fibromatosis',
#  'agyria',
#  'air',
#  'air_containing',
#  'air_contrast',
#  'air_embolism',
#  'air_trapping',
#  'airspace',
#  'airway',
#  'alignment',
#  'allergy',
#  'almost_certainly',
#  'alobar',
#  'alobar_holoprosencephaly',
#  'amnion',
#  'amorphous',
#  'amount',
#  'ampulla_of_vater',
#  'amygdala',
#  'amylase',
#  'amyloidosis',
#  'anal_canal',
#  'anal_sphincter',
#  'anaplastic_astrocytoma',
#  'anastomosis',
#  'anastomotic_leak',
#  'anechoic',
#  'anesthesia',
#  'aneurysm',
#  'angio',
#  'angiodysplasia',
#  'angiofibroma',
#  'angiography',
#  'angiomyolipoma',
#  'angioplasty',
#  'angiosarcoma',
#  'angle',
#  'angular',
#  'angulated',
#  'ankle',
#  'ankle_fracture',
#  'ankle_joint',
#  'ankle_mortise',
#  'ankylosing_spondylitis',
#  'ankylosis',
#  'annulus_fibrosus',
#  'anteater_sign',
#  'antegrade',
#  'anterior',
#  'anterior_abdominal_wall',
#  'anterior_abdominal_wall_musculature',
#  'anterior_cerebral_artery',
#  'anterior_chest_wall',
#  'anterior_commissure',
#  'anterior_cruciate_ligament',
#  'anterior_ethmoid_air_cells',
#  'anterior_longitudinal_ligament',
#  'anterior_mediastinum',
#  'anterior_pararenal_space',
#  'anterior_scalene_muscle',
#  'anterior_tibial_artery',
#  'anterior_tibial_spine',
#  'anterior_tibial_tubercle',
#  'anterior_urethra',
#  'anteroinferior_iliac_spine',
#  'anterolateral',
#  'anteroposterior_projection',
#  'anterosuperior_iliac_spine',
#  'antibiotic',
#  'antrum',
#  'aorta',
#  'aortic',
#  'aortic_arch',
#  'aortic_coarctation',
#  'aortic_dissection',
#  'aortic_root',
#  'aortic_stenosis',
#  'aortic_valve',
#  'aortitis',
#  'aortopulmonary_window',
#  'ap_view',
#  'apert_syndrome',
#  'aphthous',
#  'apical',
#  'aplasia',
#  'aponeurosis',
#  'apophysis',
#  'apophysitis',
#  'appendectomy',
#  'appendicitis',
#  'appendicolith',
#  'appendicular_skeleton',
#  'appendix',
#  'aqueduct',
#  'arachnoid_cyst',
#  'arachnoid_granulation',
#  'arachnoid_villus',
#  'arachnoiditis',
#  'arc_of_riolan',
#  'architectural_distortion',
#  'arcuate',
#  'arcuate_ligament_syndrome',
#  'area_of_enhancement',
#  'arrhythmogenic_right_ventricular_dysplasia',
#  'arterial_flow',
#  'arterial_phase',
#  'arterial_segment',
#  'arterial_switch',
#  'arterial_system',
#  'arterial_trunk',
#  'arterial_vessel',
#  'arteries',
#  'arterio',
#  'arteriography',
#  'arteriovenous_fistula',
#  'arteriovenous_malformation',
#  'arteritis',
#  'artery',
#  'arthritis',
#  'arthritis_mutilans',
#  'arthro',
#  'arthrodesis',
#  'arthrography',
#  'arthropathy',
#  'articular',
#  'articular_capsule',
#  'articular_cartilage',
#  'articular_disc',
#  'articular_facet',
#  'articular_surface',
#  'artifact',
#  'arytenoid_cartilage',
#  'ascending',
#  'ascending_aorta',
#  'ascending_cholangitis',
#  'ascending_colon',
#  'ascites',
#  'aspergillosis',
#  'aspiration',
#  'aspiration_of_fluid',
#  'aspiration_of_water',
#  'asplenia',
#  'assessment',
#  'asthma',
#  'astrocytoma',
#  'asymmetrical',
#  'asymmetry',
#  'asymptomatic',
#  'at_rest',
#  'atelectasis',
#  'atherectomy',
#  'atherosclerosis',
#  'atlanto',
#  'atlas',
#  'atresia',
#  'atria',
#  'atrial_septal_defect',
#  'atrial_septum',
#  'atrium',
#  'atrophic',
#  'atrophy',
#  'attachment',
#  'attenuation',
#  'atypical',
#  'atypical_teratoid_rhabdoid_tumor',
#  'augmentation',
#  'auricular',
#  'auricular_cartilage',
#  'autoimmune_disease',
#  'av_fistula',
#  'avascular',
#  'avascular_necrosis',
#  'average',
#  'avulsion',
#  'avulsion_fracture',
#  'axial_joint',
#  'axial_plane',
#  'axial_skeleton',
#  'axilla',
#  'axillary_artery',
#  'axillary_region',
#  'axillary_vein',
#  'azygos_continuation',
#  'azygos_vein',
#  'babygram',
#  'bacterial_infection',
#  'balloon',
#  'balloon_catheter',
#  'bamboo_spine',
#  'band_heterotopia',
#  'barium',
#  'barium_enema',
#  'barre_syndrome',
#  'basal',
#  'basal_ganglia',
#  'base_of_heart',
#  'basilar',
#  'basilar_artery',
#  'basion',
#  'basis',
#  'bathrocephaly',
#  'beaded',
#  'beak_sign',
#  'beam_hardening_artifact',
#  'bearing',
#  'before',
#  'belly',
#  'bending',
#  'benign',
#  'benign_mixed_tumor',
#  'berry_aneurysm',
#  'bezoar',
#  'bicipital_tuberosity',
#  'bicornuate_uterus',
#  'bilateral',
#  'bile_duct',
#  'bile_ducts',
#  'biliary',
#  'biliary_dilatation',
#  'biliary_system',
#  'biliary_tract',
#  'biliary_tree',
#  'bilious',
#  'bilirubinemia',
#  'bilobed',
#  'biopsy',
#  'black',
#  'bladder',
#  'bladder_base',
#  'bladder_dome',
#  'bladder_mucosa',
#  'bladder_neck',
#  'blalock',
#  'bland',
#  'bleeding',
#  'blind_pouch',
#  'block_vertebra',
#  'blockage',
#  'blood',
#  'blood_vessel',
#  'blood_vessels',
#  'bloody',
#  'blount_disease',
#  'blunted',
#  'blurring',
#  'body_of_epididymis',
#  'body_wall',
#  'bone_age',
#  'bone_cyst',
#  'bone_fragment',
#  'bone_graft',
#  'bone_grafting',
#  'bone_marrow',
#  'bones',
#  'bony_labyrinth',
#  'border',
#  'bourneville_disease',
#  'boutonniere_deformity',
#  'bowed',
#  'bowel',
#  'bowing',
#  'bowing_fracture',
#  'brachial_artery',
#  'brachial_plexus',
#  'brachiocephalic_artery',
#  'brachiocephalic_vein',
#  'brachium_pontis',
#  'brachycephaly',
#  'brain',
#  'brain_damage',
#  'brain_surface',
#  'brainstem',
#  'branching',
#  'breast',
#  'breast_cancer',
#  'breast_mass',
#  'bregma',
#  'bright',
#  'brisk',
#  'brittle_bone_disease',
#  'brodie_abscess',
#  'bronchial_tree',
#  'bronchiectasis',
#  'bronchiolectasis',
#  'bronchiolitis',
#  'bronchitis',
#  'bronchocentric',
#  'bronchography',
#  'bronchovascular',
#  'bronchus',
#  'bronchus_intermedius',
#  'brown',
#  'buccal',
#  'bucket_handle_tear',
#  'buckle_fracture',
#  'bulbar_urethra',
#  'bulging_disc',
#  'bulky',
#  'bullet',
#  'bursa',
#  'bursitis',
#  'buttock',
#  'c1',
#  'c2',
#  'c3',
#  'c3_vertebral_body',
#  'c4',
#  'c5_vertebra',
#  'c5_vertebral_body',
#  'c_sign',
#  'caffey_disease',
#  'calcaneal_tuberosity',
#  'calcaneus',
#  'calcification',
#  'calcifications',
#  'calcified',
#  'calcium',
#  'calculus',
#  'caliber',
#  'callous',
#  'calvarium',
#  'calve',
#  'calyx',
#  'cancer',
#  'capillary',
#  'capillary_hemangioma',
#  'capillary_malformation',
#  'capitate',
#  'capsule',
#  'carbon',
#  'carcinoid',
#  'carcinoid_tumor',
#  'carcinoma',
#  'carcinoma_in_situ',
#  'carcinomatosis',
#  'cardiac_apex',
#  'cardiac_chamber',
#  'cardiac_failure',
#  'cardiac_gated',
#  'cardiac_gating',
#  'cardiac_tamponade',
#  'cardiac_transplantation',
#  'cardiomyopathy',
#  'cardiovascular_complication',
#  'cardiovascular_system',
#  'carina',
#  'caroli_disease',
#  'carotid_arteries',
#  'carotid_canal',
#  'carotid_space',
#  'carpal_bone',
#  'carpal_joint',
#  'carpal_tunnel',
#  'carpometacarpal_joint',
#  'carpus',
#  'cartilage',
#  'cartilage_defect',
#  'cartilaginous',
#  'cartilaginous_tissue',
#  'caseating',
#  'castleman_disease',
#  'catheter',
#  'catheter_angiography',
#  'caudal',
#  'caudate_nucleus',
#  'cavernous',
#  'cavernous_angioma',
#  'cavernous_hemangioma',
#  'cavernous_malformation',
#  'cavernous_sinus',
#  'cavitary',
#  'cavoatrial',
#  'cecostomy',
#  'cecum',
#  'celiac_artery',
#  'celiac_axis',
#  'celiac_disease',
#  'celiac_sprue',
#  'cellulitis',
#  'cementoma',
#  'center',
#  'central',
#  'central_enhancement',
#  'central_nervous_system',
#  'central_nervous_system_neoplasm',
#  'central_neurocytoma',
#  'central_venous_catheter',
#  'centrilobular',
#  'centrum_semiovale',
#  'cerebellar_white_matter',
#  'cerebellopontine_angle',
#  'cerebellum',
#  'cerebral_aqueduct',
#  'cerebral_cortex',
#  'cerebral_hemiatrophy',
#  'cerebral_hemisphere',
#  'cerebral_palsy',
#  'cerebral_vein',
#  'cerebral_white_matter',
#  'cerebritis',
#  'cerebrospinal_fluid',
#  'cerebrovascular_disease',
#  'cerebrum',
#  'certain',
#  'cervical_fascia',
#  'cervical_ribs',
#  'cervical_spine',
#  'cervical_vertebral_body',
#  'cervical_vertebral_column',
#  'cervix',
#  'cesarean_section',
#  'chance_fracture',
#  'changed',
#  'charcot_joint',
#  'cheek',
#  'chemical_shift_artifact',
#  'chemo',
#  'chemoembolization',
#  'chemotherapy',
#  'cherubism',
#  'chest',
#  'chest_pain',
#  'chest_tube',
#  'chest_wall',
#  'chiari',
#  'chiari_malformation',
#  'child',
#  'child_abuse',
#  'choanal_atresia',
#  'cholangiocarcinoma',
#  'cholangiography',
#  'cholangiopancreatography',
#  'cholangitis',
#  'cholecystectomy',
#  'cholecystitis',
#  'choledochal_cyst',
#  'choledocholithiasis',
#  'cholelithiasis',
#  'cholesteatoma',
#  'chondroblastoma',
#  'chondrodysplasia',
#  'chondroid',
#  'chondrolysis',
#  'chondromalacia',
#  'chondromyxoid_fibroma',
#  'chondrosarcoma',
#  'chordoma',
#  'choriocarcinoma',
#  'chorion',
#  'choroid',
#  'choroid_plexus',
#  'choroid_plexus_carcinoma',
#  'choroid_plexus_cyst',
#  'choroid_plexus_papilloma',
#  'christian_disease',
#  'chronic',
#  'chronic_recurrent_multifocal_osteomyelitis',
#  'chyle',
#  'cingulate_gyrus',
#  'circle_of_willis',
#  'circular',
#  'circular_mass',
#  'circumaortic',
#  'circumference',
#  'circumferential',
#  'circumscribed',
#  'cirrhosis',
#  'cisterna_magna',
#  'clamp',
#  'clavicle',
#  'claw_hand',
#  'claw_sign',
#  'clear',
#  'clear_cell_carcinoma',
#  'clear_cell_chondrosarcoma',
#  'clear_cell_ependymoma',
#  'clear_cell_sarcoma',
#  'cleavage',
#  'click_here_for_cine_of_series_3',
#  'click_here_for_the_tumor_board_presentation_and_discussion',
#  'click_here_for_tumor_board_presentation',
#  'click_here_for_tumor_board_presentation_of_this_case',
#  'click_here_for_video_of_mri_images',
#  'clinical_finding',
#  'clinical_information',
#  'clinical_success',
#  'clitoris',
#  'clivus',
#  'closed',
#  'closed_loop_obstruction',
#  'cloud',
#  'cloverleaf_skull',
#  'clubbing',
#  'clustered',
#  'coalescent',
#  'coalition',
#  'coarctation',
#  'coarctation_of_aorta',
#  'coarse',
#  'coats_disease',
#  'coccyx',
#  'cochlea',
#  'cochlear_implant',
#  'cochlear_nerve',
#  'codman_triangle',
#  'colitis',
#  'collagenous',
#  'collapse',
#  'collapsed',
#  'collar_sign',
#  'collateral',
#  'collimator',
#  'colloid_cyst',
#  'colon',
#  'colon_wall',
#  'colonic_resection',
#  'color',
#  'colostomy',
#  'column_of_bertin',
#  'common_bile_duct',
#  'common_carotid_artery',
#  'common_duct',
#  'common_femoral_artery',
#  'common_hepatic_duct',
#  'common_iliac_artery',
#  'common_iliac_vein',
#  'communicating_hydrocephalus',
#  'compact_bone',
#  'comparison',
#  'compartment_syndrome',
#  'complete',
#  'complete_evaluation',
#  'completed',
#  'complex',
#  'complicated',
#  'complication',
#  'composition',
#  'compressed',
#  'compression',
#  'compression_fracture',
#  'computed_tomography',
#  'concave',
#  'concentration',
#  'concentric',
#  'condyle',
#  'congenital',
#  'congenital_absence',
#  'congenital_diaphragmatic_hernia',
#  'congenital_disorder',
#  'congenital_hepatic_fibrosis',
#  'congenital_malformation',
#  'congenital_stenosis',
#  'congestion',
#  'congestive',
#  'congestive_heart_failure',
#  'conglomerate',
#  'congruent',
#  'conjunctival',
#  'connective_tissue',
#  'consolidated',
#  'consolidation',
#  'constipation',
#  'constricted',
#  'constrictive_pericarditis',
#  'consult',
#  'containing',
#  'contamination',
#  'contents',
#  'contiguous',
#  'continuous',
#  'continuous_diaphragm_sign',
#  'contour',
#  'contra',
#  'contracted',
#  'contracture',
#  'contralateral',
#  'contrast',
#  'contrast_agent',
#  'contrast_barium_enema',
#  'contusion',
#  'conus_medullaris',
#  'conventional_radiography',
#  'convex',
#  'convexity',
#  'copper',
#  'cor_pulmonale',
#  'coracoid_process',
#  'cord_compression',
#  'cord_sign',
#  'core_needle',
#  'core_needle_biopsy',
#  'cornea',
#  'corona_radiata',
#  'coronal',
#  'coronal_plane',
#  'coronal_suture',
#  'coronary_arteries',
#  'coronary_artery',
#  'coronary_sinus',
#  'corpus_callosum',
#  'corpus_luteum',
#  'corpus_spongiosum',
#  'corpus_striatum',
#  'corrected',
#  'cortex',
#  'cortical',
#  'cortical_bone',
#  'corticospinal_tract',
#  'costal_cartilage',
#  'costophrenic_angle',
#  'cough',
#  'count',
#  'cranial',
#  'cranial_base',
#  'cranial_nerve',
#  'cranial_nerve_iii',
#  'cranial_nerve_v',
#  'cranial_nerve_vi',
#  'cranial_suture',
#  'craniocervical_junction',
#  'craniopharyngioma',
#  'craniosynostosis',
#  'cranium',
#  'crescent_sign',
#  'cricoid_cartilage',
#  'cricopharyngeus',
#  'crohn_disease',
#  'crossed',
#  'crossed_ectopia',
#  'croup',
#  'cruciate_ligament',
#  'csf_flow',
#  'csf_leak',
#  'ct',
#  'ct_halo_sign',
#  'cuboid',
#  'cul',
#  'curved',
#  'cutaneous',
#  'cystadenoma',
#  'cystectomy',
#  'cystic',
#  'cystic_disease',
#  'cystic_duct',
#  'cystic_fibrosis',
#  'cystic_hygroma',
#  'cystic_nephroma',
#  'cystic_partially_differentiated_nephroblastoma',
#  'cysticercosis',
#  'cystitis',
#  'cystitis_glandularis',
#  'cystography',
#  'cystotomy',
#  'cystourethrography',
#  'davidoff',
#  'de',
#  'death',
#  'debakey_type_iii',
#  'decreased',
#  'decreased_in_height',
#  'decreasing',
#  'decubitis',
#  'decubitus',
#  'decussation',
#  'dedifferentiated_chondrosarcoma',
#  'deep_vein_thrombosis',
#  'defined',
#  'defined_margin',
#  'definite',
#  'definitely',
#  'deformity',
#  'degenerated',
#  'degeneration',
#  'degenerative_disease',
#  'degenerative_disk_disease',
#  'dehiscence',
#  'delayed',
#  'delayed_enhancement',
#  'delayed_phase',
#  'delta_sign',
#  'deltoid',
#  'dementia',
#  'demineralization',
#  'demineralized_bone_matrix',
#  'demyelinating_disease',
#  'demyelination',
#  'denervation',
#  'dens_fracture',
#  'density',
#  'dental',
#  'deposition',
#  'depressed',
#  'depth',
#  'dermatomyositis',
#  'dermoid',
#  'dermoid_cyst',
#  'descending',
#  'descending_aorta',
#  'descending_colon',
#  'descending_thoracic_aorta',
#  'designation',
#  'detached',
#  'detachment',
#  'detrusor',
#  'developmental',
#  'developmental_disorder',
#  'developmental_venous_anomaly',
#  'deviated',
#  'deviation',
#  'dextroscoliosis',
#  'diabetes',
#  'diagnose',
#  'diagnosis',
#  'diagnostic',
#  'diagnostic_imaging',
#  'diameter',
#  'diaphragm',
#  'diaphragmatic_hernia',
#  'diaphragmatic_rupture',
#  'diaphyseal_fracture',
#  'diaphysis',
#  'diarrhea',
#  'diastasis',
#  'diastolic_flow',
#  'diastrophic_dwarfism',
#  'diastrophic_dysplasia',
#  'dictated',
#  'didelphys',
#  'didelphys_uterus',
#  'diffuse',
#  'diffuse_axonal_injury',
#  'diffuse_enhancement',
#  'diffuse_idiopathic_skeletal_hyperostosis',
#  'diffusion',
#  'diffusion_weighted',
#  'digit',
#  'digits',
#  'dilatation',
#  'dilated',
#  'dilated_cardiomyopathy',
#  'dilation',
#  'diminished',
#  'diploic_space',
#  'direct_extension',
#  'disappearance',
#  'disappeared',
#  'discharge',
#  'discitis',
#  'discoid',
#  'disease_progression',
#  'disease_spread',
#  'disk_kidney',
#  'dislocated',
#  'dislocation',
#  'disorder_of_bone',
#  'disorder_of_neuronal_migration',
#  'displaced',
#  'displacement',
#  'disrupted',
#  'dissection',
#  'dissociation',
#  'distal',
#  'distal_epiphysis',
#  'distal_humerus',
#  'distal_pole_of_scaphoid',
#  'distal_radioulnar_joint',
#  'distal_tibia',
#  'distance',
#  'distended',
#  'distension',
#  'distention',
#  'distorted',
#  'distraction',
#  'diuretic',
#  'diverticulitis',
#  'diverticulum',
#  'dizziness',
#  'dolicocephaly',
#  'donor',
#  'doppler',
#  'dorfman_disease',
#  'dorsal',
#  'dorsum',
#  'double',
#  'double_bubble_sign',
#  'double_wall_sign',
#  'doughnut_sign',
#  'drain',
#  'drainage',
#  'drainage_catheter',
#  'dtpa',
#  'dual_phase',
#  'ductal',
#  'ductal_dilatation',
#  'duodenal_bulb',
#  'duodenitis',
#  'duodenojejunal_junction',
#  'duodenum',
#  'duplication',
#  'duplication_cyst',
#  'dura_mater',
#  'dural',
#  'dural_ectasia',
#  'dural_venous_sinus',
#  'dyke',
#  'dynamic',
#  'dysembryoplastic_neuroepithelial_tumor',
#  'dysgenesis',
#  'dysgerminoma',
#  'dyskinesia',
#  'dysphagia',
#  'dysplasia',
#  'dystrophic',
#  'dystrophic_calcification',
#  'early_arterial_phase',
#  'early_complication',
#  'early_onset',
#  'eaten',
#  'eaten_pattern',
#  'ebstein_anomaly',
#  'eccentric',
#  'echo_imaging',
#  'echo_planar',
#  'echo_time',
#  'echocardiogram',
#  'echocardiography',
#  'echogenic',
#  'echotexture',
#  'ectasia',
#  'ectatic',
#  'ectopia',
#  'ectopic',
#  'ectopic_gastric_mucosa',
#  'ectopic_kidney',
#  'ectopic_tissue',
#  'edema',
#  'effusion',
#  'eggshell',
#  'eighth',
#  'ejaculatory_duct',
#  'ejection_fraction',
#  'elbow',
#  'elbow_joint',
#  'elevated',
#  'elliptical',
#  'elongated',
#  'embolic_material',
#  'embolism',
#  'embolization',
#  'embolus',
#  'embryo',
#  'embryonal_carcinoma',
#  'embryonal_cell_carcinoma',
#  'embryonal_sarcoma',
#  'emissary_vein',
#  'emphysema',
#  'emphysematous',
#  'empty_delta_sign',
#  'empyema',
#  'encephalitis',
#  'encephalomalacia',
#  'encephalopathy',
#  'encephalotrigeminal_angiomatosis',
#  'enchondroma',
#  'enchondromatosis',
#  'end_colostomy',
#  'end_plate',
#  'endocardium',
#  'endoleak',
#  'endolymphatic_duct',
#  'endolymphatic_sac',
#  'endometrial_cavity',
#  'endometriosis',
#  'endometritis',
#  'endopyelotomy',
#  'endoscopic',
#  'endoscopy',
#  'endothoracic',
#  'endotracheal',
#  'endotracheal_tube',
#  'endovascular_coil',
#  'engorged',
#  'enhancement',
#  'enhancement_pattern',
#  'enhancing',
#  'enlarged',
#  'enlarged_liver',
#  'enlargement',
#  'enterectomy',
#  'enteric_fistula',
#  'enteric_ganglion',
#  'enteric_nervous_system',
#  'enteritis',
#  'entero',
#  'enteroclysis',
#  'enterography',
#  'enteropathy',
#  'enterostomy',
#  'enthesophyte',
#  'entrapment_syndrome',
#  'enzyme',
#  'eosinophilic_gastroenteritis',
#  'eosinophilic_granuloma',
#  'eosinophilic_pneumonia',
#  'ependyma',
#  'ependymal_cyst',
#  'ependymoma',
#  'epicardium',
#  'epicondyle',
#  'epidermoid',
#  'epidermoid_cyst',
#  'epididymis',
#  'epidural',
#  'epidural_anesthesia',
#  'epidural_hematoma',
#  'epidural_space',
#  'epigastric_region',
#  'epigastrium',
#  'epiglottis',
#  'epiglottitis',
#  'epiphyseal_plate',
#  'epiphysis',
#  'epiploic_appendagitis',
#  'epithelioid_hemangioendothelioma',
#  'epithelium',
#  'epithelium_of_choroid_plexus',
#  'equivocal',
#  'erect',
#  'erlenmeyer_flask_deformity',
#  'eroded',
#  'erosive_osteoarthritis',
#  'esophagitis',
#  ...]

# %%
# Wordcloud for all leaf nodes of MIRC RSNa

#wordcloud = WordCloud(max_words=200).generate_from_frequencies(tf_dict.values()[0].items())
# Open a plot of the generated image.
plt.figure(figsize=(10,6))
plt.axis("off"); 
plt.imshow(WordCloud(max_words=200).generate_from_frequencies(tf_dict))
